# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanth20002k/Xtern_Summer_intern/blob/main/XTern1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('csv_googlemaps_109am.csv')
print(df)
# Out:
#                                      Name  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 13                            Bento Sushi
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# ...

# %%
df['Name']
# Out:
# 0                                Juannita's
# 1                     Big Woods Bloomington
# 2                           FARMbloomington
# 3                              Malibu Grill
# 4                            Chubbies Diner
# 5           The Irish Lion Restaurant & Pub
# 6                               Uptown Cafe
# 7                                SmokeWorks
# 8                                      Dats
# 9                               Crazy Horse
# 10                           Harry & Izzy's
# 11    Shapiro's Delicatessen at IND Airport
# 12                           Nature's Table
# 13                              Bento Sushi
# 14                                  Champps
# 15                          Farmer's Fridge
# 16                                    Vinea
# 17                   The Fan Zone Sport Bar
# 18                               McDonald's
# 19                              Chick-fil-A
# 20                           Harry & Izzy's
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
df.loc[0]
# Out:
# Name                                                           Juannita's
# Feature                          Homey Mexican place with an outdoor deck
# Full Address                    620 W Kirkwood Ave, Bloomington, IN 47404
# Street                                                 620 W Kirkwood Ave
# Municipality                                                  Bloomington
# Categories                      Mexican restaurant, Bar, Club, Sports bar
# Unnamed: 6                                                            NaN
# Phones                                    (812) 339-2340, +1 812-339-2340
# Unnamed: 8                                                            NaN
# Review Count                                                          718
# Average Rating                                                        4.0
# Review URL              https://search.google.com/local/reviews?placei...
# Google Maps URL         https://www.google.com/maps?cid=23196954978044...
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Feature', 'Full Address', 'Street', 'Municipality',
#        'Categories', 'Phones', 'Review Count', 'Average Rating', 'Review URL',
#        'Google Maps URL', 'Cid', 'Google Knowledge URL', 'Latitude',
#        'Longitude', 'Website', 'Domain', 'Opening Hours'],
#       dtype='object')

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                                         Feature  \
# Name
# Juannita's                             Homey Mexican place with an outdoor deck
# Big Woods Bloomington                         Low-key brewpub with local drafts
# FARMbloomington                               Offbeat farm-to-table destination
# Malibu Grill                                Classy, casual American destination
# Chubbies Diner                                                              NaN
# The Irish Lion Restaurant & Pub        Lively old-world tavern in historic digs
# Uptown Cafe                            All-day mainstay for Cajun-American eats
# SmokeWorks                                                                  NaN
# Dats                                        Mellow Cajun & Creole counter-serve
# Crazy Horse                                Restaurant & bar in a historic hotel
# Harry & Izzy's                         Modern twist on an old-school steakhouse
# ...

# %%
df.rename(columns={
    'Name':'NAME',
    'Feature' : 'FEATURE',
    'Full Address':'ADDRESS',
    'Phones':'Phone Numbers',
},inplace=True)
df
# Out:
#                                      NAME  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 13                            Bento Sushi
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# ...

# %%
df.dtypes
# Out:
# NAME                     object
# FEATURE                  object
# ADDRESS                  object
# Street                   object
# Municipality             object
# Categories               object
# Phone Numbers            object
# Review Count              int64
# Average Rating          float64
# Review URL               object
# Google Maps URL          object
# Cid                     float64
# Google Knowledge URL     object
# Latitude                float64
# Longitude               float64
# Website                  object
# Domain                   object
# Opening Hours            object
# dtype: object

# %%
csv_file = 'csv_googlemaps_109am.csv'
df['file name']= csv_file[:-len('.csv')]

# %%
df['serial number']= csv_file[len('.csv')]

# %%
df
# Out:
#                                      NAME  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 13                            Bento Sushi
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# ...

# %%
df.drop('serial number',inplace=True ,axis=1)

# %%
df
# Out:
#                                      NAME  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 13                            Bento Sushi
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# ...

# %%
df['Phone Numbers'].fillna('N/A',inplace=True )
df['FEATURE'].fillna('no feature',inplace=True )
df.drop('Review Count', inplace=True, axis=1)
df.drop('Review URL', inplace=True, axis=1)

# %%
df
# Out:
#                                      NAME  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 13                            Bento Sushi
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# ...

# %%
df.drop('Cid', inplace=True, axis=1)
df.drop('Domain',inplace=True,axis=1)

# %%
df
# Out:
#                                      NAME  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 13                            Bento Sushi
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# ...

# %%
df.drop('file name',inplace=True,axis =1)

# %%
df
# Out:
#                                      NAME  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 13                            Bento Sushi
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# ...

# %%
df['Opening Hours']
# Out:
# 0     Sunday:[11AM-10AM], Monday:[11AM-10PM], Tuesda...
# 1     Monday:[11AM-10PM], Tuesday:[11AM-10PM], Wedne...
# 2     Monday:[Closed], Tuesday:[5-9PM], Wednesday:[5...
# 3     Monday:[11:30AM-2PM], Tuesday:[11:30AM-2PM], W...
# 4     Monday:[11AM-10PM], Tuesday:[11AM-10PM], Wedne...
# 5     Monday:[Closed], Tuesday:[11AM-10PM], Wednesda...
# 6     Monday:[8AM-9PM], Tuesday:[8AM-9PM], Wednesday...
# 7     Monday:[10AM-10PM], Tuesday:[10AM-10PM], Wedne...
# 8     Monday:[11AM-9PM], Tuesday:[11AM-9PM], Wednesd...
# 9     Monday:[11AM-12AM], Tuesday:[11AM-12AM], Wedne...
# 10    Monday:[7AM-8PM], Tuesday:[7AM-8PM], Wednesday...
# 11    Monday:[5:30AM-6PM], Tuesday:[5:30AM-6PM], Wed...
# 12    Monday:[10AM-6PM], Tuesday:[10AM-6PM], Wednesd...
# 13                                                  NaN
# 14    Monday:[9AM-7:30PM], Tuesday:[10AM-7:30PM], We...
# 15    Monday:[Open 24 hours], Tuesday:[Open 24 hours...
# 16    Monday:[7AM-7:45PM], Tuesday:[7AM-7:45PM], Wed...
# ...

# %%
df = df.drop(labels=13, axis=0)

# %%
df
# Out:
#                                      NAME  \
# 0                              Juannita's
# 1                   Big Woods Bloomington
# 2                         FARMbloomington
# 3                            Malibu Grill
# 4                          Chubbies Diner
# 5         The Irish Lion Restaurant & Pub
# 6                             Uptown Cafe
# 7                              SmokeWorks
# 8                                    Dats
# 9                             Crazy Horse
# 10                         Harry & Izzy's
# 11  Shapiro's Delicatessen at IND Airport
# 12                         Nature's Table
# 14                                Champps
# 15                        Farmer's Fridge
# 16                                  Vinea
# 17                 The Fan Zone Sport Bar
# 18                             McDonald's
# 19                            Chick-fil-A
# 20                         Harry & Izzy's
# 21                    Mesh - Indianapolis
# ...

# %%
df.to_csv('googlemaps_filtered.csv')

# %%
import matplotlib.pyplot as plt

# %%
 df = df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   NAME                  5 non-null      object
#  1   FEATURE               5 non-null      object
#  2   ADDRESS               5 non-null      object
#  3   Street                5 non-null      object
#  4   Municipality          5 non-null      object
#  5   Categories            5 non-null      object
#  6   Phone Numbers         5 non-null      object
#  7   Average Rating        5 non-null      float64
#  8   Google Maps URL       5 non-null      object
#  9   Google Knowledge URL  5 non-null      object
#  10  Latitude              5 non-null      float64
#  11  Longitude             5 non-null      float64
#  12  Website               5 non-null      object
#  13  Opening Hours         5 non-null      object
# dtypes: float64(3), object(11)
# ...

# %%
rating_numbers = df.loc[:,'Average Rating'].values
names_list = df.loc[:,'NAME']

# %%
help(plt.plot)

# %%
plt.plot(names_list,rating_numbers)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')
plt.plot(names_list,rating_numbers, marker = '.')

# %%
type(rating_numbers)
# Out:
# numpy.ndarray

# %%
type('Average Rating')
# Out:
# str

# %%
#Big Woods Bloomington has the highest rating and many would love to go to this place

# %%
df.loc[1]
# Out:
# NAME                                                Big Woods Bloomington
# FEATURE                                 Low-key brewpub with local drafts
# ADDRESS                             116 N Grant St, Bloomington, IN 47408
# Street                                                     116 N Grant St
# Municipality                                                  Bloomington
# Categories                               Restaurant, Brewpub, Event venue
# Phone Numbers                             (812) 335-1821, +1 812-335-1821
# Average Rating                                                        4.4
# Google Maps URL         https://www.google.com/maps?cid=10399309206750...
# Google Knowledge URL    https://www.google.com/search?kgmid=/g/11bbrhm...
# Latitude                                                        39.167113
# Longitude                                                      -86.529607
# Website                               http://www.bigwoodsrestaurants.com/
# ...

# %%
#here are the details of Big Woods Bloomington and the phone numbers and their opening and closing timings
